# %% [markdown]
# # Revisão 02

# %%
import pandas as pd

# %%
df = pd.read_csv('cursos-prouni.csv')

# %%
# Listar as primeiras 5 linhas
df.head(5)
# Out:
# (41447, 20)

# %%
# Listar 5 linhas aleatórias
df.sample(5)
# Out:
#                grau              turno  mensalidade  bolsa_integral_cotas  \
# 7432    Tecnológico            Noturno       983.26                   1.0
# 24643  Licenciatura  Curso a Distância       325.00                   0.0
# 27216  Licenciatura  Curso a Distância       299.00                   1.0
# 13841   Bacharelado           Matutino       654.36                   NaN
# 12819   Bacharelado            Noturno       696.20                   8.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 7432                    2.0                  1.0                  2.0
# 24643                   1.0                  NaN                  NaN
# 27216                   NaN                  NaN                  NaN
# 13841                   NaN                  1.0                  1.0
# 12819                   2.0                  NaN                  NaN
#
#               curso_id            curso_busca           cidade_busca uf_busca  \
# ...

# %%
# O formato do dataframe - shape não é uma função, e sim uma propriedade, portanto não usa ()
df.shape
# Out:
# (41447, 20)

# %%
df1 = pd.read_csv?

# %%
# Criar um novo dataframe pulando as 5 primeiras linhas
df1 = pd.read_csv('cursos-prouni.csv', skiprows=5)
df1.head(2)
# Out:
#    Bacharelado  Integral  9674.34    4     1   5   2  65899611932754  \
# 0  Bacharelado  Integral   9650.0  8.0  15.0 NaN NaN     65781564964
# 1  Bacharelado  Integral   9564.0  3.0   5.0 NaN NaN     65788486984
#
#    Medicina           Rio Branco  AC  MTIwMjAwNDAwNDAx  \
# 0  Medicina  Presidente Prudente  SP  MzUwODAzNjQxNDA2
# 1  Medicina              Marilia  SP  MzUwOTAzODI5MDA1
#
#         Faculdade Barão do Rio Branco - FAB  \
# 0  Universidade do Oeste Paulista - UNOESTE
# 1          Universidade de Marília - UNIMAR
#
#   CAMPUS  - RIO BRANCO - JARDIM EUROPA II - Jardim Europa II  658996  \
# 0  CAMPUS I  SEDE ADMINISTRATIVA PRESIDENTE PRUDE...          657815
# 1                UNIDADE SEDE - Campus Universitario          657884
#
#   Medicina.1  758.32  723.94  734.92  711.26
# 0   Medicina  738.92  728.86     NaN     NaN
# 1   Medicina  744.16  735.00     NaN     NaN

# %%
df1.shape
# Out:
# (41442, 20)

# %%
# Mostrar os títulos das colunas
df.columns
# Out:
# Index(['grau', 'turno', 'mensalidade', 'bolsa_integral_cotas',
#        'bolsa_integral_ampla', 'bolsa_parcial_cotas', 'bolsa_parcial_ampla',
#        'curso_id', 'curso_busca', 'cidade_busca', 'uf_busca', 'cidade_filtro',
#        'universidade_nome', 'campus_nome', 'campus_id', 'nome',
#        'nota_integral_ampla', 'nota_integral_cotas', 'nota_parcial_ampla',
#        'nota_parcial_cotas'],
#       dtype='object')

# %%
# Sobrescrever o df1 com 3 colunas específicas
df1 = df[['mensalidade', 'cidade_busca', 'uf_busca']]
df1
# Out:
#        mensalidade          cidade_busca uf_busca
# 0          9999.99          Campo Grande       MS
# 1          9836.40               Crateus       CE
# 2          9715.61             Sao Paulo       SP
# 3          9689.34               Crateus       CE
# 4          9674.34            Rio Branco       AC
# ...            ...                   ...      ...
# 41442       149.00  Paraiso do Tocantins       TO
# 41443       144.00           Sao VIcente       SP
# 41444       139.00              Brasilia       DF
# 41445       139.00               Vitoria       ES
# 41446       139.00              Santarem       PA
#
# [41447 rows x 3 columns]

# %%
# Maior mensalidade
df1['mensalidade'].max()
# Out:
# 9999.99

# %%
# Listar as principais informações 
df1.describe()
# Out:
#         mensalidade
# count  41447.000000
# mean     622.636966
# std      606.442296
# min      139.000000
# 25%      278.000000
# 50%      393.350000
# 75%      825.000000
# max     9999.990000

# %%
# Listar a maior mensalidade por estado
df1.groupby('uf_busca')['mensalidade'].max()
# Out:
# uf_busca
# AC    9674.34
# AL    7290.00
# AM    2127.05
# AP    3607.62
# BA    9048.00
# CE    9836.40
# DF    6757.92
# ES    6022.28
# GO    6484.47
# MA    8281.38
# MG    9350.00
# MS    9999.99
# MT    9208.00
# PA    8508.54
# PB    8350.00
# PE    7250.00
# PI    8402.00
# PR    8466.72
# RJ    9023.07
# RN    6505.09
# RO    6909.97
# RR    1463.05
# RS    8329.95
# SC    6922.15
# SE    6490.00
# SP    9715.61
# TO    7800.00
# Name: mensalidade, dtype: float64

# %%
df.head(5)
# Out:
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
# 1  Bacharelado   Noturno      9836.40                   1.0
# 2  Bacharelado  Integral      9715.61                   2.0
# 3  Bacharelado   Noturno      9689.34                   3.0
# 4  Bacharelado  Integral      9674.34                   4.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   5.0                  6.0                 10.0
# 3                   2.0                  NaN                  NaN
# 4                   1.0                  5.0                  2.0
#
#           curso_id curso_busca  cidade_busca uf_busca     cidade_filtro  \
# 0     706710394154    Medicina  Campo Grande       MS  NTAwMjAwNDAyNzA0
# ...

# %%
# Quantos cursos de medicina
df[df['curso_busca'] == 'Medicina'].count()
# Out:
# grau                    124
# turno                   124
# mensalidade             124
# bolsa_integral_cotas    122
# bolsa_integral_ampla    117
# bolsa_parcial_cotas      23
# bolsa_parcial_ampla      22
# curso_id                124
# curso_busca             124
# cidade_busca            124
# uf_busca                124
# cidade_filtro           124
# universidade_nome       124
# campus_nome             124
# campus_id               124
# nome                    124
# nota_integral_ampla     122
# nota_integral_cotas     107
# nota_parcial_ampla       24
# nota_parcial_cotas       21
# dtype: int64

# %%
# Mensalidade > 500 e < 800
df[(df['mensalidade'] < 800) & (df['mensalidade'] > 500)].sort_values('mensalidade')
# Out:
#               grau              turno  mensalidade  bolsa_integral_cotas  \
# 17685  Bacharelado  Curso a Distância       500.10                   1.0
# 17684  Bacharelado  Curso a Distância       500.54                   0.0
# 17683  Tecnológico            Noturno       500.61                   NaN
# 17682  Tecnológico            Noturno       500.64                   1.0
# 17681  Tecnológico            Noturno       500.73                   2.0
# ...            ...                ...          ...                   ...
# 10753  Bacharelado           Matutino       799.07                   1.0
# 10752  Tecnológico            Noturno       799.20                   1.0
# 10751  Bacharelado            Noturno       799.35                   4.0
# 10750  Bacharelado            Noturno       799.54                   1.0
# 10749  Bacharelado           Matutino       799.80                   2.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %%
# Selecionar o valor da mensalidade da linha 33
df.loc[33, 'mensalidade']
# Out:
# 7946.35
