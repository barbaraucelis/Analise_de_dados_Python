# %%
import pandas as pd

# %%
df = pd.read_csv('sia112018.csv', sep=';', encoding='cp1252')

# %%
df.sample(10)
# Out:
#         ano_mes  cod_estabelecimento_cnes  \
# 80700    201811                     10499
# 137568   201811                     10464
# 20909    201811                     10510
# 133142   201811                   9414754
# 32311    201811                   2816741
# 151264   201811                   9317368
# 87272    201811                   2779056
# 7467     201811                   9317368
# 53841    201811                   9317368
# 79309    201811                   9271961
#
#                        estabelecimento_cnes        complexidade  cod_grupo  \
# 80700   HRT HOSPITAL REGIONAL DE TAGUATINGA   Alta complexidade          4
# 137568                                 HRAN  Média complexidade          3
# 20909    HOSPITAL UNIVERSITARIO DE BRASILIA   Alta complexidade          3
# 133142            POLICLINICA DE SOBRADINHO  Média complexidade          3
# 32311      FARMACIA DE ALTO CUSTO - ASA SUL   Alta complexidade          6
# ...

# %%
df_01 = df[['estabelecimento_cnes','complexidade']]

# %%
df_01.columns
# Out:
# Index(['estabelecimento_cnes', 'complexidade'], dtype='object')

# %%
df_01.columns = ['Hospital', 'Complexidade']

# %%
df_01.columns
# Out:
# Index(['Hospital', 'Complexidade'], dtype='object')

# %%
df['grupo'].value_counts()
# Out:
# 02 - Procedimentos com Finalidade Diagnóstica     75825
# 03 - Procedimentos Clínicos                       54006
# 06 - Medicamentos                                 38398
# 04 - Procedimentos Cirúrgicos                      4025
# 05 - Transplantes de Orgãos, Tecidos e Células     3943
# 07 - Órteses, Próteses e Materiais Especiais       2944
# 01- Ações de Promoção e Prevenção em Saúde          677
# 08 - Ações Complementares da Atenção à Saúde        464
# Name: grupo, dtype: int64

# %%
df_01['Hospital'].str.contains('UNIVERSITARIO')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 180277    False
# 180278    False
# 180279    False
# 180280    False
# 180281    False
# Name: Hospital, Length: 180282, dtype: bool

# %%
df[df['estabelecimento_cnes'].str.contains('UNIVERSITARIO')]
# Out:
#         ano_mes  cod_estabelecimento_cnes                estabelecimento_cnes  \
# 5260     201811                     10510  HOSPITAL UNIVERSITARIO DE BRASILIA
# 5281     201811                     10510  HOSPITAL UNIVERSITARIO DE BRASILIA
# 6944     201811                     10510  HOSPITAL UNIVERSITARIO DE BRASILIA
# 6945     201811                     10510  HOSPITAL UNIVERSITARIO DE BRASILIA
# 6946     201811                     10510  HOSPITAL UNIVERSITARIO DE BRASILIA
# ...         ...                       ...                                 ...
# 180255   201811                     10510  HOSPITAL UNIVERSITARIO DE BRASILIA
# 180256   201811                     10510  HOSPITAL UNIVERSITARIO DE BRASILIA
# 180274   201811                     10510  HOSPITAL UNIVERSITARIO DE BRASILIA
# 180275   201811                     10510  HOSPITAL UNIVERSITARIO DE BRASILIA
# 180276   201811                     10510  HOSPITAL UNIVERSITARIO DE BRASILIA
#
# ...

# %%
df_prouni = pd.read_csv('cursos-prouni.csv')
df_prouni.head()
# Out:
#           grau     turno  mensalidade  bolsa_integral_cotas  \
# 0  Bacharelado  Integral      9999.99                  15.0
# 1  Bacharelado   Noturno      9836.40                   1.0
# 2  Bacharelado  Integral      9715.61                   2.0
# 3  Bacharelado   Noturno      9689.34                   3.0
# 4  Bacharelado  Integral      9674.34                   4.0
#
#    bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# 0                  14.0                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   5.0                  6.0                 10.0
# 3                   2.0                  NaN                  NaN
# 4                   1.0                  5.0                  2.0
#
#           curso_id curso_busca  cidade_busca uf_busca     cidade_filtro  \
# 0     706710394154    Medicina  Campo Grande       MS  NTAwMjAwNDAyNzA0
# ...

# %%
df_prouni[df_prouni['mensalidade'] > 500]
# Out:
#               grau              turno  mensalidade  bolsa_integral_cotas  \
# 0      Bacharelado           Integral      9999.99                  15.0
# 1      Bacharelado            Noturno      9836.40                   1.0
# 2      Bacharelado           Integral      9715.61                   2.0
# 3      Bacharelado            Noturno      9689.34                   3.0
# 4      Bacharelado           Integral      9674.34                   4.0
# ...            ...                ...          ...                   ...
# 17681  Tecnológico            Noturno       500.73                   2.0
# 17682  Tecnológico            Noturno       500.64                   1.0
# 17683  Tecnológico            Noturno       500.61                   NaN
# 17684  Bacharelado  Curso a Distância       500.54                   0.0
# 17685  Bacharelado  Curso a Distância       500.10                   1.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %%
df_prouni[(df_prouni['mensalidade'] > 500) & (df_prouni['mensalidade'] < 800)]
# Out:
#               grau              turno  mensalidade  bolsa_integral_cotas  \
# 10749  Bacharelado           Matutino       799.80                   2.0
# 10750  Bacharelado            Noturno       799.54                   1.0
# 10751  Bacharelado            Noturno       799.35                   4.0
# 10752  Tecnológico            Noturno       799.20                   1.0
# 10753  Bacharelado           Matutino       799.07                   1.0
# ...            ...                ...          ...                   ...
# 17681  Tecnológico            Noturno       500.73                   2.0
# 17682  Tecnológico            Noturno       500.64                   1.0
# 17683  Tecnológico            Noturno       500.61                   NaN
# 17684  Bacharelado  Curso a Distância       500.54                   0.0
# 17685  Bacharelado  Curso a Distância       500.10                   1.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %%
df_prouni.describe()
# Out:
#         mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# count  41447.000000          32520.000000          25404.000000
# mean     622.636966              1.535394              2.513541
# std      606.442296              2.191578              3.019549
# min      139.000000              0.000000              1.000000
# 25%      278.000000              0.000000              1.000000
# 50%      393.350000              1.000000              1.000000
# 75%      825.000000              2.000000              3.000000
# max     9999.990000             58.000000             67.000000
#
#        bolsa_parcial_cotas  bolsa_parcial_ampla      curso_id     campus_id  \
# count          8828.000000         13041.000000  4.144700e+04  4.144700e+04
# mean              1.873018             8.632544  4.207360e+13  6.786530e+05
# std               2.336403            18.372991  6.061552e+13  6.398410e+05
# min               1.000000             1.000000  2.248801e+07  2.240000e+02
# ...

# %%
df_prouni.count()
# Out:
# grau                    41447
# turno                   41447
# mensalidade             41447
# bolsa_integral_cotas    32520
# bolsa_integral_ampla    25404
# bolsa_parcial_cotas      8828
# bolsa_parcial_ampla     13041
# curso_id                41447
# curso_busca             41447
# cidade_busca            41447
# uf_busca                41447
# cidade_filtro           41447
# universidade_nome       41447
# campus_nome             41447
# campus_id               41447
# nome                    41447
# nota_integral_ampla     32520
# nota_integral_cotas     16802
# nota_parcial_ampla      16350
# nota_parcial_cotas       5519
# dtype: int64

# %%
df_prouni.groupby('uf_busca')['mensalidade'].max()
# Out:
# uf_busca
# AC    9674.34
# AL    7290.00
# AM    2127.05
# AP    3607.62
# BA    9048.00
# CE    9836.40
# DF    6757.92
# ES    6022.28
# GO    6484.47
# MA    8281.38
# MG    9350.00
# MS    9999.99
# MT    9208.00
# PA    8508.54
# PB    8350.00
# PE    7250.00
# PI    8402.00
# PR    8466.72
# RJ    9023.07
# RN    6505.09
# RO    6909.97
# RR    1463.05
# RS    8329.95
# SC    6922.15
# SE    6490.00
# SP    9715.61
# TO    7800.00
# Name: mensalidade, dtype: float64

# %%
df_prouni.loc?
